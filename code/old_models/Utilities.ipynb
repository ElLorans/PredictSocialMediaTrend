# %% [raw]
# # I wanted to put all useful stuff here... did not have the time, file is incomplete

# %%
# SET INDEX TO DATETIME
df['date'] = pd.to_datetime(df['date']) # maybe eliminate?
df.set_index('date')

# %%
# GET MOVING AVERAGE
df_moving_avg = df.rolling(7, win_type='triang').sum()

# %%
# PLOT LINEAR REGRESSION
import seaborn as sns
sns.regplot(x=df_fabi.index,y=df_fabi.Pesticides,color='blue', marker='+')

# %%
# GET RIGHT order COEFFICIENT FOR ARIMA model
# CODE FROM https://www.digitalocean.com/community/tutorials/a-guide-to-time-series-forecasting-with-arima-in-python-3
# Define the p, d and q parameters to take any value between 0 and 2

import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))

# %%
a = """
"Farmer"
0.4424086
"Pesticides"
0.3589021
"Food_Contamination"
0.4184478
"Industry"
0.3742559
"Dairy_Health_Impact"
0.8356321
"Forest"
0.6222305
"Waste"
0.5852549
"Workers"
0.7276756
"Cow"
0.465278
"Government"
0.5383728
"ImportExport"
0.6358398
"Chemical"
0.4341251
"Deforestation_Agriculture"
1.159261
"Lactose_Intolerant"
11.21912
"Food_Climat_Impact"
1.465823
"Employment"
0.6984734
"Policy"
1.459606
"Poverty"
0.5745928
"Biodiversity"
0.5223489
"Price"
14.2102
"Brexit"
1.230221
"Food_Waste"
1.036457
"Industrial_Agriculture"
0.5167094
"Soil"
0.6293653
"Natural"
0.5242256
"Payment_Wages"
0.565425
"Cancer"
0.4565607
"MentalHealth"
0.9972359
"GMO"
0.4395096
"Sugar"
0.943463
"Factory"
0.8253124
"Packaging"
0.7139301
"PalmOil"
0.8243449
"Immigration"
0.9091644
"Taste"
0.5378098
"Pollinators"
1.251557
"Shortage"
1.240294
"Glyphosate"
0.5023661
"Animal_Welfare"
1.679592
"CEO"
0.8181279
"Recycling"
1.00311
"Vegan_Against_Dairy"
0.6786499
"Almond_milk"
0.4094411
"Vitamin"
0.7091234
"Allergy"
0.513038
"Gut_Digestion"
0.6664252
"Ingredient_Scrutiny"
0.6058203
"Fats"
0.7537347
"Lactose"
0.3601019
"Seeds"
0.5520759
"Protein"
0.5716404
"Milk_Prices"
0.8283124
"Bacteria"
0.8994112
"Industry_Impacy_Health"
0.7740302
"Obesity"
0.9374278
"Food_access"
1.441085
"Antibiotics"
1.28574
"Reusable"
0.7651319
"Plastic_Ocean"
0.8111597
"Retail"
0.7190765
"Hormone"
0.7618073
"Label"
0.7368736
"Water_Scarcity"
1.143354
"Chlorpyrifos"
1.342511
"Bank"
1.473113
"Xenophobic"
3.43397
"Sustainable_Diet"
1.268596
"Meat_Impact_Climate"
2.145451
"Chlorine"
2.590856
"Baby_Milk"
0.8402782
"Residues"
0.6597952
"Additive"
0.7326699
"Diabetes"
0.7546582
"Soya_milk"
0.8418712
"Processed_Food"
0.6356966
"Feminism"
Inf
"Transparency"
1.198721
"Religion"
0.9419446
"Breastfeeding"
0.7513641
"Gluten"
0.606849
"Skincar"
1.165258
"Cocoa"
0.5845676
"Monoculture"
1.046903
"Shareholders"
1.669626
"Microplastics"
0.8833329
"Infant_Nutrition"
2.220091
"Veganism"
0.9372442
"Carbohydrates"
0.8358758
"Fertility"
1.732882
"Biodegradable"
1.960014
"Microwave"
0.8327324
"Sulfoxaflor"
NaN
"Organic_Authenticity"
0.8480338
"Traceability"
4.351624
"NanoParticles"
1.12366
"Aluminium"
1.079274
"Probiotics"
1.62583
"Atrazine"
2.839974
"Perchlorate"
1.567404
"Dairy_Industry_Lie"
6.312808
"Genetically_Modified_Animal"
4.263352
"Milk_Sales"
1.79334
"Overpackaging"
3.127609
"""

# %%
b = a.split("\n")

# %%
b
# Out:
# ['"Farmer"',
#  '0.4424086',
#  '"Pesticides"',
#  '0.3589021',
#  '"Food_Contamination"',
#  '0.4184478',
#  '"Industry"',
#  '0.3742559',
#  '"Dairy_Health_Impact"',
#  '0.8356321',
#  '"Forest"',
#  '0.6222305',
#  '"Waste"',
#  '0.5852549',
#  '"Workers"',
#  '0.7276756',
#  '"Cow"',
#  '0.465278',
#  '"Government"',
#  '0.5383728',
#  '"ImportExport"',
#  '0.6358398',
#  '"Chemical"',
#  '0.4341251',
#  '"Deforestation_Agriculture"',
#  '1.159261',
#  '"Lactose_Intolerant"',
#  '11.21912',
#  '"Food_Climat_Impact"',
#  '1.465823',
#  '"Employment"',
#  '0.6984734',
#  '"Policy"',
#  '1.459606',
#  '"Poverty"',
#  '0.5745928',
#  '"Biodiversity"',
#  '0.5223489',
#  '"Price"',
#  '14.2102',
#  '"Brexit"',
#  '1.230221',
#  '"Food_Waste"',
#  '1.036457',
#  '"Industrial_Agriculture"',
#  '0.5167094',
#  '"Soil"',
#  '0.6293653',
#  '"Natural"',
#  '0.5242256',
#  '"Payment_Wages"',
#  '0.565425',
#  '"Cancer"',
#  '0.4565607',
#  '"MentalHealth"',
#  '0.9972359',
#  '"GMO"',
# ...

# %%
c = dict(zip(b[::2], b[1::2]))

# %%
d = dict()
for key in c:
    try:
        d[key] = int(c[key])
    except:
        d[key] = c[key]
# Out:
# {'"Farmer"': '0.4424086',
#  '"Pesticides"': '0.3589021',
#  '"Food_Contamination"': '0.4184478',
#  '"Industry"': '0.3742559',
#  '"Dairy_Health_Impact"': '0.8356321',
#  '"Forest"': '0.6222305',
#  '"Waste"': '0.5852549',
#  '"Workers"': '0.7276756',
#  '"Cow"': '0.465278',
#  '"Government"': '0.5383728',
#  '"ImportExport"': '0.6358398',
#  '"Chemical"': '0.4341251',
#  '"Deforestation_Agriculture"': '1.159261',
#  '"Lactose_Intolerant"': '11.21912',
#  '"Food_Climat_Impact"': '1.465823',
#  '"Employment"': '0.6984734',
#  '"Policy"': '1.459606',
#  '"Poverty"': '0.5745928',
#  '"Biodiversity"': '0.5223489',
#  '"Price"': '14.2102',
#  '"Brexit"': '1.230221',
#  '"Food_Waste"': '1.036457',
#  '"Industrial_Agriculture"': '0.5167094',
#  '"Soil"': '0.6293653',
#  '"Natural"': '0.5242256',
#  '"Payment_Wages"': '0.565425',
#  '"Cancer"': '0.4565607',
#  '"MentalHealth"': '0.9972359',
#  '"GMO"': '0.4395096',
#  '"Sugar"': '0.943463',
#  '"Factory"': '0.8253124',
# ...

# %%
d = dict()
for k in c:
    d[k] = float(c[k])

# %%
d
# Out:
# {'"Farmer"': 0.4424086,
#  '"Pesticides"': 0.3589021,
#  '"Food_Contamination"': 0.4184478,
#  '"Industry"': 0.3742559,
#  '"Dairy_Health_Impact"': 0.8356321,
#  '"Forest"': 0.6222305,
#  '"Waste"': 0.5852549,
#  '"Workers"': 0.7276756,
#  '"Cow"': 0.465278,
#  '"Government"': 0.5383728,
#  '"ImportExport"': 0.6358398,
#  '"Chemical"': 0.4341251,
#  '"Deforestation_Agriculture"': 1.159261,
#  '"Lactose_Intolerant"': 11.21912,
#  '"Food_Climat_Impact"': 1.465823,
#  '"Employment"': 0.6984734,
#  '"Policy"': 1.459606,
#  '"Poverty"': 0.5745928,
#  '"Biodiversity"': 0.5223489,
#  '"Price"': 14.2102,
#  '"Brexit"': 1.230221,
#  '"Food_Waste"': 1.036457,
#  '"Industrial_Agriculture"': 0.5167094,
#  '"Soil"': 0.6293653,
#  '"Natural"': 0.5242256,
#  '"Payment_Wages"': 0.565425,
#  '"Cancer"': 0.4565607,
#  '"MentalHealth"': 0.9972359,
#  '"GMO"': 0.4395096,
#  '"Sugar"': 0.943463,
#  '"Factory"': 0.8253124,
#  '"Packaging"': 0.7139301,
#  '"PalmOil"': 0.8243449,
# ...

# %%
my_dict = {k.replace('"', "") : v for k, v in sorted(d.items(), key=lambda item: item[1])}

# %%
import csv
with open('test.csv', 'w') as f:
    for key in my_dict.keys():
        f.write("%s,%s\n"%(key,my_dict[key]))
